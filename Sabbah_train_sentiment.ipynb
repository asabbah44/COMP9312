# %% [markdown]
# <a href="https://colab.research.google.com/github/asabbah44/COMP9312/blob/master/Sabbah_train_sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Verify that you have the GPU recognized 
# !nvidia-smi
# Out:
# Wed Jun  1 19:13:46 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Git clone COMP9312 repo

# %%
# !rm -rf /content/COMP9312
# !git clone https://{TOKEN}@github.com/asabbah44/COMP9312.git
# Out:
# Cloning into 'COMP9312'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 49 (delta 17), reused 44 (delta 12), pack-reused 0
# Unpacking objects: 100% (49/49), done.

# %% [markdown]
# # Install dependencies

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.2 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 55.8 MB/s
# ...
#      |████████████████████████████████| 86 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 66.7 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %% [markdown]
# # Model training

# %%
# Make output directory
# !mkdir /content/output/

# %%
import sys
import argparse
sys.path.append('/content/COMP9312/')

# %%
from comp9312.classify.train import main

# %%
args_dict = {
    "output_path": "/content/output/",
    "train_path": "/content/COMP9312/data/AJGT/train.csv",
    "test_path": "/content/COMP9312/data/AJGT/test.csv",
    "val_path": "/content/COMP9312/data/AJGT/val.csv",
    "seed": 1,
    "max_epochs": 10,
    "batch_size": 8,
    "bert_model": "aubmindlab/bert-base-arabertv2",
    "num_workers": 1,
    "gpus": [0],
    "learning_rate": 0.00001
}
args = argparse.Namespace()
args.__dict__ = args_dict

# %%
main(args)
# Out:
# Downloading:   0%|          | 0.00/703k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/611 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/384 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/518M [00:00<?, ?B/s]
# Some weights of the model checkpoint at aubmindlab/bert-base-arabertv2 were not used when initializing BertModel: ['cls.predictions.decoder.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...
